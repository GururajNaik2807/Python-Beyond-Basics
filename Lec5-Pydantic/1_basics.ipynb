# %%
from pydantic import BaseModel

# %%
class employee_schema(BaseModel):
    name:str
    salary:int

obj=employee_schema(name="Gururaj",salary=1020)
obj
# if i do any errors like no in name it will give error 
# obj1=employee_schema(name=102,salary=120393)
# obj1
# Out:
# employee_schema(name='Gururaj', salary=1020)

# %%
#Coersion and srict type 
# so in coersion if pydantic can convert the thing into the selected type it will convert and 
# not give the error but iff  there is no possibilty then it gives error 
# But in strict type there is the strict constraint if the datatype is not in that form then direct error
from pydantic import StrictInt,BaseModel,StrictStr
class strictemployeeschema(BaseModel):
    employeename:StrictStr
    salary:StrictInt
obj1=strictemployeeschema(name="100",salary="namrata")
obj1
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[6], line 9
#       5 from pydantic import StrictInt,BaseModel,StrictStr
#       6 class strictemployeeschema(BaseModel):
#       7     employeename:StrictStr
#       8     salary:StrictInt
# ----> 9 obj1=strictemployeeschema(name="100",salary="namrata")
#      10 obj1
#
# File d:\Advanced Python Beyond Basics\.venv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
# ...
